# %% [markdown]
# # Week 5 - Edge AI Introduction and Federated Learning
#
# ## 1. Notations
#
# ### 1.1 - Introduction of Edge AI
#
# ### 1.2 - Training and Inference
#
# 1. Training@Cloud | Inference@Edge
# 2. Training-Inference@Edge
# 3. Collaborative training or inference
#     - Not all the original data, generated at edge, is necessarily transmitted to the cloud
#     - Due to the different configurations, and manufacturers, of the Edge Devices, the features (or trained models) shared between the nodes
#
# ### 1.3 - Federated Learning (1/3)
#
# 1. Distributed Learning
# 2. Federated Learning
#
# ### 1.4 - Federated Learning (2/3)
#
# 1. FedAvg vs SGD
# 2. Secure Federated Learning
#
#
# ### 1.5 - Federated Learning (3/3)
#
# Federated Learning Categorization
# 1. Horizontal federated learning
# 2. Vertical federated learning
# 3. Federated transfer learning
#
# An edge AI framework
# - Sedna

# %% [markdown]
# ## 2. Quizzes
#
# ### 2.1 - Introduction of Edge AI
#
# **Question 1**
#
# Which of the following statements about Edge AI is true?
#
# - [ ] Edge AI can transfer data from the cloud-side data center to the edge-side storage space.
# - [ ] Edge AI will completely replace the cloud-centric AI paradigm in the future.
# - [x] Edge AI aims at offloading AI capabilities closer to the user.
#
# **Question 2**
#
# Which of the following describes the motivation of Edge AI?
#
# - [ ] Most of the data is generated from data center.
# - [x] Reduce the bandwidth of data transmission
# - [x] Ensure offline autonomy of applications
# - [x] It can better protect data privacy.
# - [x] Improve the real-time capability and interactivity of applications
#
# **Question 3**
#
# Which of the following are **not** suitable applications of Edge AI?
#
# - [x] Cloud gaming
# - [ ] Satellite
# - [ ] VR/AR
# - [ ] Video Conferencing system
#
# ### 2.2 Training and Inference
#
# **Question 1**
#
# Which of the following statements about training and inference in the Edge AI context are true?
#
# - [x] Training and inference on Edge devices can somehow solve the non-IID problem.
# - [ ] If we perform training on the cloud and inference on the Edge device, we have to transfer massive Edge data to update the cloud-side model.
# - [ ] Collaborative inference refers to the use of multiple cloud nodes for joint inference.
# - [ ] We can send the edge-side data to the cloud node and do collaborative training on the cloud.
#
# **Question 2**
#
# In the collaborative training scenario, the cloud node does not need to transmit data with the edge node because the cloud node already has enough data to train the model. The edge nodes need to share data because their data volume is too small. Is the above statement correct?
#
# - [x] No
# - [ ] Yes
#
# ### 2.3 Federated Learning (1/3)
#
# **Question 1**
#
# Which of the following factors contributed to the emergence of federated learning?
#
# - [x] Strengthened data protection regulations, e.g., EU’s GDPR
# - [x] Data silos problem
# - [x] Mobile and Edge devices create massive amounts of data every day.
# - [ ] The edge-side data have relatively high quality, and thus they should be applied to a distributed machine learning system.
#
# **Question 2**
#
# Which of the following statements are true?
#
# - [x] Federated learning and distributed machine learning have similar characteristics, but federated learning faces more stringent challenges, such as strict privacy protection requirements and heterogeneous clients.
# - [ ] Participants in federated studies are the federal states of each country.
# - [ ] Because it forbid transferring patients’ data to others, federated learning cannot be applied to the medical and health field.
# - [ ] The origin of federated learning is a technical project organized and supported by the federal government.
#
# **Question 3**
#
# Which of the following are characteristics about Federated learning?
#
# - [ ] Federated learning is the opposite of distributed learning.
# - [x] Traditional distributed learning will centrally control all nodes, while federated learning emphasizes autonomy.
# - [x] It faces the problem of non-IID and unstable nodes.
# - [x] It emphasizes stricter privacy and security
#
# ### 2.4 Federated Learning (2/3)
#
# **Question 1**
#
# Is the FedAvg algorithm a federated learning method for averaging gradients?
#
# - [ ] Yes
# - [x] No
#
# **Question 2 (confusing question)**
#
# Consider the following figure representing conventional distributed learning.
# What should be filled in the dashed box?
#
# - [x] Gradients
# - [ ] Weights
#
# **Question 3**
#
# Which of the following statements about secure federated learning are true?
#
# - [x] Defending the privacy leakage and improving the robustness are important research topics in federated learning.
# - [ ] Unfortunately, the training data information can be reversely leaked through the model activations.
# - [ ] As long as the user data does not leave the local device, the training data information cannot be leaked.
#
# ### 2.5 Federated Learning (3/3)
#
# **Question 1**
#
# Which of the following statements about federated learning categorization are true?
#
# - [ ] Vertical federated learning is suitable for the use cases of similar features and a union of samples.
# - [x] Federated transfer learning deals with the use cases with little overlapping of samples, features.
# - [x] Horizontal federated learning is suitable for the use cases of similar features and a union of samples.
#
# **Question 2**
#
# Which of the following statements about encrypted training in vertical federated learning is incorrect?
#
# - [ ] The third-party C sends the public key to parties A and B to encrypt the transmit.
# - [x] Model update for party C
# - [ ] Encrypted gradients summary
# - [ ] Encrypted interaction to obtain the intermediate gradients.
